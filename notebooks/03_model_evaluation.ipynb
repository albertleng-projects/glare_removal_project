# %%
# Install necessary packages
# !pip install torch torchvision matplotlib tqdm

import re
import torch
import torch.nn as nn
import torch.nn.functional as f
from torchvision import transforms
import matplotlib.pyplot as plt
from tqdm import tqdm
from PIL import Image
from pathlib import Path

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


# ===========================
# 1️⃣ Load Trained Model
# ===========================
class UNetGenerator(nn.Module):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 64, 4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, 4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 64, 4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, 1, 4, stride=2, padding=1),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x


# Load trained model
# final_model_epoch_5.pth is the model saved after 5 epochs. It is used as it has the lowest validation loss amongst the models trained.
MODEL_PATH = Path("../models/checkpoints/final_model_epoch_5.pth")
model = UNetGenerator().to(device)

try:
    model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
    model.eval()  # Set model to evaluation mode
    print("✅ Model loaded successfully.")
except RuntimeError as e:
    print(f"❌ Error loading model: {e}")


# ===========================
# 2️⃣ Load Validation Dataset
# ===========================
class GlareRemovalDataset(torch.utils.data.Dataset):
    def __init__(self, glare_dir, gt_dir, transform_fn=None):
        # Extract filenames that match the expected patterns
        glare_files = sorted(glare_dir.glob("glare_*.png"))
        gt_files = sorted(gt_dir.glob("gt_*.png"))

        # Use regex to extract numeric part from filenames
        glare_dict = {re.search(r"glare_(\d+)\.png", file.name).group(1): file for file in glare_files if
                      re.search(r"glare_(\d+)\.png", file.name)}
        gt_dict = {re.search(r"gt_(\d+)\.png", file.name).group(1): file for file in gt_files if
                   re.search(r"gt_(\d+)\.png", file.name)}

        # Find common numeric keys and sort them
        common_keys = sorted(set(glare_dict.keys()) & set(gt_dict.keys()), key=int)

        # Store matched file paths
        self.image_pairs = [(glare_dict[k], gt_dict[k]) for k in common_keys]
        self.transform = transform_fn

    def __len__(self):
        return len(self.image_pairs)

    def __getitem__(self, index):
        glare_path, gt_path = self.image_pairs[index]

        glare_image = Image.open(glare_path).convert("L")  # Convert to grayscale
        gt_image = Image.open(gt_path).convert("L")  # Convert to grayscale

        if self.transform:
            glare_image = self.transform(glare_image)
            gt_image = self.transform(gt_image)

        return glare_image, gt_image


# Define transforms
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor in [0,1] range
])

DATA_DIR = Path("../data/SD1")
VAL_GLARE_DIR = DATA_DIR / "processed_val"
VAL_GT_DIR = DATA_DIR / "processed_val"

# Load dataset
val_dataset = GlareRemovalDataset(VAL_GLARE_DIR, VAL_GT_DIR, transform)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=1, shuffle=False)

# ===========================
# 3️⃣ Evaluate Model
# ===========================
criterion_l1 = nn.L1Loss()
total_val_loss = 0

with torch.no_grad():
    for glare, gt in tqdm(val_loader, desc="Evaluating"):
        glare, gt = glare.to(device), gt.to(device)
        fake_gt = model(glare)
        fake_gt = f.interpolate(fake_gt, size=(512, 512), mode='bilinear', align_corners=False)

        # Compute L1 loss
        val_loss = criterion_l1(fake_gt, gt)
        total_val_loss += val_loss.item()

avg_val_loss = total_val_loss / len(val_loader)
print(f"📊 Average Validation Loss: {avg_val_loss:.4f}")


# ===========================
# 4️⃣ Visualize Results
# ===========================
def display_images(original, predicted, ground_truth):
    fig, ax = plt.subplots(1, 3, figsize=(12, 4))

    ax[0].imshow(original.squeeze().cpu(), cmap="gray")
    ax[0].set_title("Glare Image")

    ax[1].imshow(predicted.squeeze().cpu(), cmap="gray")
    ax[1].set_title("Predicted Image")

    ax[2].imshow(ground_truth.squeeze().cpu(), cmap="gray")
    ax[2].set_title("Ground Truth")

    for a in ax:
        a.axis("off")

    plt.show()


# Show results for a few validation images
num_samples = 20
sample_indices = torch.randperm(len(val_dataset))[:num_samples]

with torch.no_grad():
    for idx in sample_indices:
        glare_img, gt_img = val_dataset[idx]
        glare_img = glare_img.unsqueeze(0).to(device)  # Add batch dimension
        predicted_img = model(glare_img)
        predicted_img = f.interpolate(predicted_img, size=(512, 512), mode='bilinear', align_corners=False)

        display_images(glare_img, predicted_img, gt_img)
# Out:
# ...
# Using device: cpu
# ✅ Model loaded successfully.
# Evaluating: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 650/650 [00:49<00:00, 13.08it/s]
# 📊 Average Validation Loss: 0.0562
